# %%
import pandas as pd
import numpy as np
from pykrx import stock
import time
date = '20220712'
stock_list = pd.DataFrame({'종목코드':stock.get_market_ticker_list(market="ALL")})
stock_list['종목명'] = stock_list['종목코드'].map(lambda x: stock.get_market_ticker_name(x))
stock_fud = pd.DataFrame(stock.get_market_fundamental_by_ticker(date=date, market="ALL"))
stock_fud = stock_fud.reset_index()
stock_fud.rename(columns={'티커':'종목코드'}, inplace=True)
result = pd.merge(stock_list, stock_fud, left_on='종목코드', right_on='종목코드', how='outer')
stock_price = stock.get_market_ohlcv_by_ticker(date=date, market="ALL")
stock_price = stock_price.reset_index()
stock_price.rename(columns={'티커':'종목코드'}, inplace=True)
result1 = pd.merge(result, stock_price, left_on='종목코드', right_on='종목코드', how='outer')
result1 = result1.replace([0], np.nan)
result1 = result1.dropna(axis=0)
result1['내재가치'] = (result1['BPS'] + (result1['EPS']) * 10) / 2
result1['내재가치/종가'] = (result1['내재가치'] / result1['종가'])
# result1.to_excel("stocks.xlsx")

# %%
len(result1)
# Out:
# 1046

# %%
for i in range(len(result1)):
    code = result1['종목코드'].iloc[i]
    name = result1['종목명'].iloc[i]
    
    df = stock.get_market_ohlcv_by_date("20220501", date, code)
    df.to_excel(f"./stocks lists/{code}_{name}_stocks.xlsx")
    time.sleep(0.7)
    print(f"Success : {name}")
# Out:
# Success : AJ네트웍스
# Success : APS홀딩스
# Success : AP시스템
# Success : AP위성
# Success : BGF
# Success : BGF리테일
# Success : BNK금융지주
# Success : BYC
# Success : CJ
# Success : CJ ENM
# Success : CJ제일제당
# Success : CJ프레시웨이
# Success : CNH
# Success : CS홀딩스
# Success : DB금융투자
# Success : DB손해보험
# Success : DB하이텍
# Success : DGB금융지주
# Success : DI동일
# Success : DL
# Success : DL건설
# Success : DL이앤씨
# Success : DMS
# Success : DN오토모티브
# Success : DSR
# Success : DSR제강
# Success : E1
# Success : F&F
# Success : F&F홀딩스
# Success : GS
# Success : GST
# Success : GS건설
# Success : GS리테일
# Success : HB테크놀러지
# Success : HDC
# Success : HDC랩스
# Success : HDC현대EP
# Success : HDC현대산업개발
# Success : HK이노엔
# Success : HMM
# Success : HRS
# Success : ISC
# Success : JB금융지주
# Success : JW생명과학
# Success : JYP Ent.
# Success : KBG
# Success : KB금융
# Success : KCC건설
# Success : KCC글라스
# Success : KCI
# Success : KCTC
# Success : KC그린홀딩스
# Success : KG ETS
# Success : KG모빌리언스
# Success : KG스틸
# Success : KG이니시스
# Success : KG케미칼
# Success : KH바텍
# Success : KISCO홀딩스
# Success : KNN
# Success : KPX케미칼
# Success : KPX홀딩스
# Success : KSS해운
# Success : KT
# Success : KT&G
# Success : KTcs
# Success : KTis
# Success : LF
# Success : LG
# Success : LG디스플레이
# Success : LG생활건강
# Success : LG유플러스
# Success : LG이노텍
# Success : LG전자
# Success : LG헬로비전
# Success : LG화학
# Success : LIG넥스원
# Success : LS
# Success : LS ELECTRIC
# Success : LS전선아시아
# Success : LX세미콘
# Success : LX인터내셔널
# Success : LX하우시스
# Success : MH에탄올
# Success : NAVER
# Success : NE능률
# Success : NH투자증권
# Success : NICE
# Success : NICE평가정보
# Success : NI스틸
# Success : NPC
# Success : OCI
# Success : PI첨단소재
# Success : PN풍년
# Success : POSCO홀딩스
# Success : RFHIC
# Success : S&K폴리텍
# Success : S-Oil
# Success : SBS
# Success : 삼성전자
# Success : 삼성증권
# Success : 삼성출판사
# Success : 삼성카드
# Success : 삼성화재
# Success : 삼아알미늄
# Success : 삼아제약
# Success : 삼양사
# Success : 삼양식품
# Success : 삼양옵틱스
# Success : 삼양통상
# Success : 삼양패키징
# Success : 삼양홀딩스
# Success : 삼영무역
# Success : 삼영전자
# Success : 삼원강재
# Success : 삼익THK
# Success : 삼익악기
# Success : 삼일기업공사
# Success : 삼지전자
# Success : 삼진
# Success : 삼진엘앤디
# Success : 삼진제약
# Success : 삼천리
# Success : 삼천리자전거
# Success : 삼표시멘트
# Success : 삼현철강
# Success : 삼호개발
# Success : 삼화왕관
# Success : 삼화전기
# Success : 삼화콘덴서
# Success : 상상인
# Success : 상신브레이크
# Success : 상신이디피
# Success : 상아프론테크
# Success : 새론오토모티브
# Success : 샘표
# Success : 샘표식품
# Success : 서린바이오
# Success : 서부T&D
# Success : 서암기계공업
# Success : 서연
# Success : 서연이화
# Success : 서연탑메탈
# Success : 서울가스
# Success : 서울바이오시스
# Success : 서울반도체
# Success : 서울옥션
# Success : 서원
# Success : 서원인텍
# Success : 서진시스템
# Success : 서플러스글로벌
# Success : 서한
# Success : 서호전기
# Success : 서흥
# Success : 서희건설
# Success : 선광
# Success : 선진
# Success : 선진뷰티사이언스
# Success : 성도이엔지
# Success : 성문전자
# Success : 성보화학
# Success : 성신양회
# Success : 성우테크론
# Success : 성우하이텍
# Success : 성창오토텍
# Success : 세경하이테크
# Success : 세명전기
# Success : 세방
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     173         try:
# --> 174             conn = connection.create_connection(
#     175                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      95     if err is not None:
# ---> 96         raise err
#      97
#
# ~\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      85                 sock.bind(source_address)
# ---> 86             sock.connect(sa)
#      87             return sock
#
# OSError: [WinError 10014] 호출에 대한 포인터 인수를 사용하려는 동안 시스템에서 잘못된 포인터 주소를 감지했습니다
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     393             else:
# --> 394                 conn.request(method, url, **httplib_request_kw)
#     395
#
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in request(self, method, url, body, headers)
#     238             headers["User-Agent"] = _get_default_user_agent()
# --> 239         super(HTTPConnection, self).request(method, url, body=body, headers=headers)
#     240
#
# ~\Anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1278         """Send a complete request to the server."""
# -> 1279         self._send_request(method, url, body, headers, encode_chunked)
#    1280
#
# ~\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1324             body = _encode(body, 'body')
# -> 1325         self.endheaders(body, encode_chunked=encode_chunked)
#    1326
#
# ~\Anaconda3\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1273             raise CannotSendHeader()
# -> 1274         self._send_output(message_body, encode_chunked=encode_chunked)
#    1275
#
# ~\Anaconda3\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1033         del self._buffer[:]
# -> 1034         self.send(msg)
#    1035
#
# ~\Anaconda3\lib\http\client.py in send(self, data)
#     973             if self.auto_open:
# --> 974                 self.connect()
#     975             else:
#
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     204     def connect(self):
# --> 205         conn = self._new_conn()
#     206         self._prepare_conn(conn)
#
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     185         except SocketError as e:
# --> 186             raise NewConnectionError(
#     187                 self, "Failed to establish a new connection: %s" % e
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x00000228BA590910>: Failed to establish a new connection: [WinError 10014] 호출에 대한 포인터 인수를 사용하려는 동안 시스템에서 잘못된 포인터 주소를 감지했습니다
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     754
# --> 755             retries = retries.increment(
#     756                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# ~\Anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     573         if new_retry.is_exhausted():
# --> 574             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     575
#
# MaxRetryError: HTTPConnectionPool(host='fchart.stock.naver.com', port=80): Max retries exceeded with url: /sise.nhn?symbol=004490&timeframe=day&count=73&requestType=0 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x00000228BA590910>: Failed to establish a new connection: [WinError 10014] 호출에 대한 포인터 인수를 사용하려는 동안 시스템에서 잘못된 포인터 주소를 감지했습니다'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9176/3662361200.py in <module>
#       3     name = result1['종목명'].iloc[i]
#       4
# ----> 5     df = stock.get_market_ohlcv_by_date("20220501", date, code)
#       6     df.to_excel(f"./stocks lists/{code}_{name}_stocks.xlsx")
#       7     time.sleep(0.7)
#
# ~\Anaconda3\lib\site-packages\pykrx\stock\api.py in get_market_ohlcv_by_date(fromdate, todate, ticker, freq, adjusted, name_display)
#     237
#     238     if adjusted:
# --> 239         df = naver.get_market_ohlcv_by_date(fromdate, todate, ticker)
#     240         # 상장 폐지 종목은 네이버에 데이터가 존재하지 않는다.
#     241         # - Empty DataFrame을 반환
#
# ~\Anaconda3\lib\site-packages\pykrx\website\naver\wrap.py in get_market_ohlcv_by_date(fromdate, todate, ticker)
#      13     elapsed = today - strtd + pd.Timedelta(days=1)
#      14
# ---> 15     xml = Sise().fetch(ticker, elapsed.days)
#      16
#      17     result = []
#
# ~\Anaconda3\lib\site-packages\pykrx\website\naver\core.py in fetch(self, ticker, count, timeframe)
#      20         :return:
#      21         """
# ---> 22         result = self.read(symbol=ticker, timeframe=timeframe, count=count, requestType="0")
#      23         return result.text
#      24
#
# ~\Anaconda3\lib\site-packages\pykrx\website\comm\webio.py in read(self, **params)
#       8
#       9     def read(self, **params):
# ---> 10         resp = requests.get(self.url, headers=self.headers, params=params)
#      11         return resp
#      12
#
# ~\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPConnectionPool(host='fchart.stock.naver.com', port=80): Max retries exceeded with url: /sise.nhn?symbol=004490&timeframe=day&count=73&requestType=0 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x00000228BA590910>: Failed to establish a new connection: [WinError 10014] 호출에 대한 포인터 인수를 사용하려는 동안 시스템에서 잘못된 포인터 주소를 감지했습니다'))
